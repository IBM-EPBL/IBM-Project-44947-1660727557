# %% [markdown]
# ## importing required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams

# %% [markdown]
# ## Load the dataset

# %%
df=pd.read_csv('Mall_Customers.csv')
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %% [markdown]
# ## Visualizations

# %% [markdown]
# ## Univariate Analysis

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams

# %% [markdown]
# ## Line Chart

# %%
x=[1,2,3,4,5,6,7,8,9]
y=[2,4,6,8,9,7,3,4,5]

# %%
plt.plot(x,y)
plt.show()

# %%
df.Age.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Pie Chart

# %%
plt.pie(df.Gender.value_counts(),[0.1,0],shadow=True,colors=['red','pink'],labels=['M','F'],autopct='%1.1f')
plt.title('Gender')
plt.show()

# %% [markdown]
# ## Bar Graph

# %%
plt.figure(figsize=(15,10))
sns.barplot(df.Age,df.iloc[:,3])
# Out:
# C:\Users\Tamilarasan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Annual Income (k$)'>

# %% [markdown]
# ## Histogram

# %%
plt.hist(df.Age)
# Out:
# (array([31., 19., 34., 29., 16., 26., 15., 10.,  6., 14.]),
#  array([18. , 23.2, 28.4, 33.6, 38.8, 44. , 49.2, 54.4, 59.6, 64.8, 70. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ## Scatter Plot

# %%
sns.scatterplot(df.Age,df.iloc[:,3])
# Out:
# C:\Users\Tamilarasan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Annual Income (k$)'>

# %% [markdown]
# ## Box Plot

# %%
plt.figure(figsize=(15,10))
sns.boxplot(df.Age,df.iloc[:,3])
# Out:
# C:\Users\Tamilarasan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Annual Income (k$)'>

# %% [markdown]
# ## Multivariate Analysis

# %% [markdown]
# ## Pair Plot

# %%
import seaborn 
import pandas
data=pandas.read_csv('Mall_Customers.csv')
seaborn.pairplot(data)

# %% [markdown]
# ## Descriptive Statistics

# %%
## import required libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams

# %%
## loading datasets

df=pd.read_csv('Mall_Customers.csv')
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.shape
# Out:
# (200, 5)

# %%
df.info
# Out:
# <bound method DataFrame.info of      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]>

# %%
df.isnull().any()
# Out:
# CustomerID                False
# Gender                    False
# Age                       False
# Annual Income (k$)        False
# Spending Score (1-100)    False
# dtype: bool

# %%
## for numerical column use mean or median for null value replacements
## for categoriccal columns use mode for null value replacements.

# %%
df.Age.value_counts()
# Out:
# 32    11
# 35     9
# 19     8
# 31     8
# 30     7
# 49     7
# 40     6
# 38     6
# 47     6
# 27     6
# 36     6
# 23     6
# 34     5
# 20     5
# 29     5
# 50     5
# 48     5
# 21     5
# 24     4
# 18     4
# 28     4
# 67     4
# 59     4
# 54     4
# 43     3
# 60     3
# 45     3
# 39     3
# 33     3
# 37     3
# 22     3
# 25     3
# 46     3
# 68     3
# 52     2
# 44     2
# 66     2
# 57     2
# 26     2
# 53     2
# 42     2
# 63     2
# 70     2
# 51     2
# 58     2
# 65     2
# 41     2
# 55     1
# 69     1
# 64     1
# 56     1
# Name: Age, dtype: int64

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %% [markdown]
# ## Outliers And Replace The Outliers

# %% [markdown]
# ## Outlier Detection

# %%
sns.boxplot(df.Age)
# Out:
# C:\Users\Tamilarasan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# ## Check for categorical columns and perform encoding

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %% [markdown]
# ## Encoding

# %% [markdown]
# ## Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df.Gender = le.fit_transform(df.Gender)
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1       1   19                  15                      39
# 1           2       1   21                  15                      81
# 2           3       0   20                  16                       6
# 3           4       0   23                  16                      77
# 4           5       0   31                  17                      40

# %% [markdown]
# ## On Hot Encoding

# %%
df_main=pd.get_dummies(df,columns=['Gender'])
df_main.head()
# Out:
#    CustomerID  Age  Annual Income (k$)  Spending Score (1-100)  Gender_0  \
# 0           1   19                  15                      39         0
# 1           2   21                  15                      81         0
# 2           3   20                  16                       6         1
# 3           4   23                  16                      77         1
# 4           5   31                  17                      40         1
#
#    Gender_1
# 0         1
# 1         1
# 2         0
# 3         0
# 4         0

# %%
df_main.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)  \
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000
#
#          Gender_0    Gender_1
# count  200.000000  200.000000
# mean     0.560000    0.440000
# std      0.497633    0.497633
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      1.000000    0.000000
# 75%      1.000000    1.000000
# max      1.000000    1.000000

# %%
df_main.corr()
# Out:
#                         CustomerID       Age  Annual Income (k$)  \
# CustomerID                1.000000 -0.026763            0.977548
# Age                      -0.026763  1.000000           -0.012398
# Annual Income (k$)        0.977548 -0.012398            1.000000
# Spending Score (1-100)    0.013835 -0.327227            0.009903
# Gender_0                 -0.057400 -0.060867           -0.056410
# Gender_1                  0.057400  0.060867            0.056410
#
#                         Spending Score (1-100)  Gender_0  Gender_1
# CustomerID                            0.013835 -0.057400  0.057400
# Age                                  -0.327227 -0.060867  0.060867
# Annual Income (k$)                    0.009903 -0.056410  0.056410
# Spending Score (1-100)                1.000000  0.058109 -0.058109
# Gender_0                              0.058109  1.000000 -1.000000
# Gender_1                             -0.058109 -1.000000  1.000000

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df_main.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Scaling the data

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(df)
data_scaled[0:5]
# Out:
# array([[0.        , 1.        , 0.01923077, 0.        , 0.3877551 ],
#        [0.00502513, 1.        , 0.05769231, 0.        , 0.81632653],
#        [0.01005025, 0.        , 0.03846154, 0.00819672, 0.05102041],
#        [0.01507538, 0.        , 0.09615385, 0.00819672, 0.7755102 ],
#        [0.0201005 , 0.        , 0.25      , 0.01639344, 0.39795918]])

# %% [markdown]
# ## Perform Clustering algorithm

# %%
from sklearn import cluster

# %%
from sklearn.cluster import KMeans
km = KMeans()
res = km.fit_predict(data_scaled)
res
# Out:
# array([4, 4, 0, 0, 0, 0, 6, 0, 1, 0, 1, 0, 6, 0, 4, 4, 0, 4, 1, 0, 4, 4,
#        6, 4, 6, 4, 6, 4, 6, 0, 1, 0, 1, 4, 6, 0, 6, 0, 6, 0, 6, 4, 1, 0,
#        6, 0, 6, 0, 0, 0, 6, 4, 0, 1, 6, 1, 6, 1, 0, 1, 1, 4, 6, 6, 1, 4,
#        6, 6, 4, 0, 1, 6, 6, 6, 1, 4, 6, 4, 0, 6, 1, 4, 1, 6, 0, 1, 6, 0,
#        0, 6, 6, 4, 1, 6, 0, 4, 6, 0, 1, 4, 0, 6, 1, 4, 1, 0, 6, 1, 1, 1,
#        1, 0, 7, 4, 0, 0, 6, 6, 6, 6, 2, 7, 3, 2, 7, 3, 5, 2, 5, 2, 5, 2,
#        7, 3, 5, 3, 7, 2, 5, 3, 7, 2, 7, 3, 5, 2, 5, 3, 7, 2, 5, 2, 7, 3,
#        7, 3, 5, 3, 5, 3, 7, 3, 5, 3, 5, 3, 5, 3, 7, 2, 5, 2, 5, 2, 7, 3,
#        5, 2, 5, 2, 7, 3, 5, 3, 7, 2, 7, 2, 7, 3, 7, 3, 5, 3, 7, 3, 7, 2,
#        5, 2])

# %%
data = pd.DataFrame(data_scaled, columns = df.columns)
data.head()
# Out:
#    CustomerID  Gender       Age  Annual Income (k$)  Spending Score (1-100)
# 0    0.000000     1.0  0.019231            0.000000                0.387755
# 1    0.005025     1.0  0.057692            0.000000                0.816327
# 2    0.010050     0.0  0.038462            0.008197                0.051020
# 3    0.015075     0.0  0.096154            0.008197                0.775510
# 4    0.020101     0.0  0.250000            0.016393                0.397959

# %%
data['kclus']  = pd.Series(res)
data.head()
# Out:
#    CustomerID  Gender       Age  Annual Income (k$)  Spending Score (1-100)  \
# 0    0.000000     1.0  0.019231            0.000000                0.387755
# 1    0.005025     1.0  0.057692            0.000000                0.816327
# 2    0.010050     0.0  0.038462            0.008197                0.051020
# 3    0.015075     0.0  0.096154            0.008197                0.775510
# 4    0.020101     0.0  0.250000            0.016393                0.397959
#
#    kclus
# 0      4
# 1      4
# 2      0
# 3      0
# 4      0

# %%
data['kclus'].unique()
# Out:
# array([4, 0, 6, 1, 7, 2, 3, 5])

# %%
data['kclus'].value_counts()
# Out:
# 6    36
# 0    34
# 1    25
# 4    24
# 3    22
# 7    20
# 5    20
# 2    19
# Name: kclus, dtype: int64

# %%
import matplotlib.pyplot as plt

fig,ax = plt.subplots(figsize=(15,8))
sns.scatterplot(x=data['Annual Income (k$)'],
                y=data['Spending Score (1-100)'],
                hue=data['kclus'],
                palette='PuBuGn')
plt.show()

# %%
ind = data.iloc[:,0:5]
ind.head()
# Out:
#    CustomerID  Gender       Age  Annual Income (k$)  Spending Score (1-100)
# 0    0.000000     1.0  0.019231            0.000000                0.387755
# 1    0.005025     1.0  0.057692            0.000000                0.816327
# 2    0.010050     0.0  0.038462            0.008197                0.051020
# 3    0.015075     0.0  0.096154            0.008197                0.775510
# 4    0.020101     0.0  0.250000            0.016393                0.397959

# %%
dep = data.iloc[:,5:]
dep.head()
# Out:
#    kclus
# 0      4
# 1      4
# 2      0
# 3      0
# 4      0

# %% [markdown]
# ## Independent and dependent variable splits

# %% [markdown]
# ## Independent variables

# %%
X= data.iloc[:,:-1]
X.head()
# Out:
#    CustomerID  Gender       Age  Annual Income (k$)  Spending Score (1-100)
# 0    0.000000     1.0  0.019231            0.000000                0.387755
# 1    0.005025     1.0  0.057692            0.000000                0.816327
# 2    0.010050     0.0  0.038462            0.008197                0.051020
# 3    0.015075     0.0  0.096154            0.008197                0.775510
# 4    0.020101     0.0  0.250000            0.016393                0.397959

# %% [markdown]
# ## Dependent variables

# %%
y = data.kclus
y
# Out:
# 0      4
# 1      4
# 2      0
# 3      0
# 4      0
#       ..
# 195    3
# 196    7
# 197    2
# 198    5
# 199    2
# Name: kclus, Length: 200, dtype: int32

# %%
X.head()
# Out:
#    CustomerID  Gender       Age  Annual Income (k$)  Spending Score (1-100)
# 0    0.000000     1.0  0.019231            0.000000                0.387755
# 1    0.005025     1.0  0.057692            0.000000                0.816327
# 2    0.010050     0.0  0.038462            0.008197                0.051020
# 3    0.015075     0.0  0.096154            0.008197                0.775510
# 4    0.020101     0.0  0.250000            0.016393                0.397959

# %% [markdown]
# ## Scaling the independent variables

# %%
from sklearn.preprocessing import scale
X_scaled = pd.DataFrame(scale(X),columns=X.columns)
X_scaled.head()
# Out:
#    CustomerID    Gender       Age  Annual Income (k$)  Spending Score (1-100)
# 0   -1.723412  1.128152 -1.424569           -1.738999               -0.434801
# 1   -1.706091  1.128152 -1.281035           -1.738999                1.195704
# 2   -1.688771 -0.886405 -1.352802           -1.700830               -1.715913
# 3   -1.671450 -0.886405 -1.137502           -1.700830                1.040418
# 4   -1.654129 -0.886405 -0.563369           -1.662660               -0.395980

# %% [markdown]
# ## Spliting the data for training and testing

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test =train_test_split(X_scaled,y, test_size=0.3,random_state=0)

# %%
X_train
# Out:
#      CustomerID    Gender       Age  Annual Income (k$)  \
# 131    0.545603  1.128152  0.010765            0.398489
# 96    -0.060623 -0.886405  0.584899           -0.021375
# 181    1.411639 -0.886405 -0.491602            1.390894
# 19    -1.394318 -0.886405 -0.276302           -1.433644
# 153    0.926659 -0.886405 -0.061002            0.665675
# ..          ...       ...       ...                 ...
# 67    -0.562924 -0.886405  2.091999           -0.479408
# 192    1.602167  1.128152 -0.419835            2.001605
# 117    0.303113 -0.886405  0.728432            0.169472
# 47    -0.909338 -0.886405 -0.850435           -0.784763
# 172    1.255753  1.128152 -0.204535            1.009200
#
#      Spending Score (1-100)
# 131                0.962775
# 96                -0.124229
# 181                1.389812
# 19                 1.855671
# 153                1.001596
# ..                      ...
# 67                -0.085407
# 192               -1.638270
# 117                0.341630
# 47                -0.124229
# 172               -1.560627
#
# [140 rows x 5 columns]

# %%
y_train
# Out:
# 131    2
# 96     6
# 181    3
# 19     0
# 153    3
#       ..
# 67     6
# 192    5
# 117    6
# 47     0
# 172    5
# Name: kclus, Length: 140, dtype: int32

# %%
X_train.shape
# Out:
# (140, 5)

# %%
y_train.shape
# Out:
# (140,)

# %%
X_test
# Out:
#      CustomerID    Gender       Age  Annual Income (k$)  \
# 18    -1.411639  1.128152  0.943732           -1.433644
# 170    1.221111  1.128152  0.082532            1.009200
# 107    0.129905  1.128152  1.087265            0.093133
# 98    -0.025981  1.128152  0.656665            0.016795
# 177    1.342356  1.128152 -0.850435            1.047369
# 182    1.428960  1.128152  0.513132            1.429063
# 5     -1.636808 -0.886405 -1.209269           -1.662660
# 146    0.805414  1.128152  0.656665            0.627505
# 12    -1.515563 -0.886405  1.374332           -1.548152
# 152    0.909338 -0.886405  0.369598            0.665675
# 61    -0.666848  1.128152 -1.424569           -0.555747
# 125    0.441678 -0.886405 -0.563369            0.360319
# 180    1.394318 -0.886405 -0.132768            1.390894
# 154    0.943979 -0.886405  0.584899            0.665675
# 80    -0.337754  1.128152  1.302565           -0.250391
# 7     -1.602167 -0.886405 -1.137502           -1.624491
# 33    -1.151828  1.128152 -1.496335           -1.051949
# 130    0.528282  1.128152  0.584899            0.398489
# 37    -1.082545 -0.886405 -0.635135           -1.013780
# 74    -0.441678  1.128152  1.446099           -0.250391
# 183    1.446281 -0.886405 -0.706902            1.429063
# 145    0.788093  1.128152 -0.778669            0.627505
# 45    -0.943979 -0.886405 -1.065735           -0.822933
# 159    1.030583 -0.886405 -0.635135            0.665675
# 60    -0.684169  1.128152  2.235532           -0.555747
# 123    0.407037  1.128152  0.010765            0.322150
# 179    1.376998  1.128152 -0.276302            1.238216
# 185    1.480922  1.128152 -0.635135            1.467233
# 122    0.389716 -0.886405  0.082532            0.322150
# 44    -0.961300 -0.886405  0.728432           -0.822933
# 16    -1.446281 -0.886405 -0.276302           -1.509983
# 55    -0.770772  1.128152  0.584899           -0.670255
# 150    0.874697  1.128152  0.297832            0.665675
# 111    0.199188 -0.886405 -1.424569            0.093133
# 22    -1.342356 -0.886405  0.513132           -1.357305
# 189    1.550205 -0.886405 -0.204535            1.619911
# 129    0.510961  1.128152 -0.061002            0.398489
# 4     -1.654129 -0.886405 -0.563369           -1.662660
# 83    -0.285792 -0.886405  0.513132           -0.250391
# 106    0.112585 -0.886405  1.948466            0.093133
# 134    0.597565  1.128152 -1.352802            0.474828
# 66    -0.580244 -0.886405  0.297832           -0.479408
# 26    -1.273073 -0.886405  0.441365           -1.242797
# 113    0.233830  1.128152 -1.424569            0.131303
# 168    1.186470 -0.886405 -0.204535            1.009200
# 63    -0.632206 -0.886405  1.087265           -0.517577
# 8     -1.584846  1.128152  1.804932           -1.586321
# 75    -0.424358  1.128152 -0.922202           -0.250391
# 118    0.320433 -0.886405  0.871965            0.245811
# 143    0.753452 -0.886405 -0.491602            0.589336
# 71    -0.493641 -0.886405  0.584899           -0.441239
# 124    0.424358 -0.886405 -1.137502            0.360319
# 184    1.463601 -0.886405  0.154298            1.467233
# 97    -0.043302 -0.886405 -0.850435           -0.021375
# 149    0.857376  1.128152 -0.348068            0.665675
# 24    -1.307715 -0.886405  1.087265           -1.242797
# 30    -1.203790  1.128152  1.517865           -1.166458
# 160    1.047904 -0.886405  1.230799            0.703844
# 40    -1.030583 -0.886405  1.876699           -0.861102
# 56    -0.753452 -0.886405  0.871965           -0.632086
#
#      Spending Score (1-100)
# 18                -0.823017
# 170               -1.444162
# 107               -0.163051
# 98                -0.318337
# 177                0.729845
# 182               -1.366519
# 5                  1.001596
# 146               -0.551266
# 12                -1.366519
# 152               -1.172411
# 61                 0.186343
# 125                1.040418
# 180               -0.706552
# 154               -1.327697
# 80                 0.031057
# 7                  1.700384
# 33                 1.622741
# 130               -1.599448
# 37                 0.885132
# 74                -0.124229
# 183                1.467455
# 145                1.816849
# 45                 0.574559
# 159                0.885132
# 60                 0.225165
# 123                1.583920
# 179                1.545098
# 185                1.816849
# 122                0.302808
# 44                -0.861839
# 16                -0.590088
# 55                -0.357158
# 150               -1.288876
# 111                0.147522
# 22                -1.754735
# 189                1.350990
# 129                0.962775
# 4                 -0.395980
# 83                -0.240694
# 106               -0.007764
# 134               -1.754735
# 66                -0.007764
# 26                -0.706552
# 113               -0.163051
# 168               -0.900660
# 63                 0.341630
# 8                 -1.832378
# 75                 0.147522
# 118               -0.279515
# 143                1.428633
# 71                -0.318337
# 124               -0.823017
# 184               -0.434801
# 97                -0.007764
# 149                1.545098
# 24                -1.405340
# 30                -1.793556
# 160               -0.590088
# 40                -0.590088
# 56                -0.007764

# %%
y_test
# Out:
# 18     1
# 170    5
# 107    1
# 98     1
# 177    2
# 182    5
# 5      0
# 146    5
# 12     6
# 152    7
# 61     4
# 125    3
# 180    7
# 154    7
# 80     1
# 7      0
# 33     4
# 130    5
# 37     0
# 74     1
# 183    3
# 145    2
# 45     0
# 159    3
# 60     1
# 123    2
# 179    2
# 185    2
# 122    3
# 44     6
# 16     0
# 55     1
# 150    5
# 111    0
# 22     6
# 189    3
# 129    2
# 4      0
# 83     6
# 106    6
# 134    5
# 66     6
# 26     6
# 113    4
# 168    7
# 63     6
# 8      1
# 75     4
# 118    6
# 143    3
# 71     6
# 124    7
# 184    7
# 97     0
# 149    2
# 24     6
# 30     1
# 160    7
# 40     6
# 56     6
# Name: kclus, dtype: int32

# %%
X_test.shape
# Out:
# (60, 5)

# %%
y_test.shape
# Out:
# (60,)

# %% [markdown]
# ## Building the model

# %%
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

# %%
ridge = Ridge()
lasso = Lasso()

# %%
ridge.fit(X_train,y_train)
# Out:
# Ridge()

# %%
lasso.fit(X_train,y_train)
# Out:
# Lasso()

# %% [markdown]
# ## Training and Testing the model

# %%
y_train_pred = ridge.predict(X_train)
y_train_pred
# Out:
# array([2.4411757 , 3.98089514, 3.08836057, 1.07862038, 3.35954142,
#        3.14784601, 3.68158483, 2.68913529, 1.95674405, 3.66929753,
#        3.26748103, 4.13870101, 2.40666347, 4.0477178 , 4.49170356,
#        4.01039852, 3.8404749 , 3.40825499, 1.74927741, 1.72698751,
#        2.95701767, 3.23529092, 4.3557849 , 3.42725393, 4.05603216,
#        3.92997859, 3.83556626, 3.03454893, 5.79412529, 2.78249862,
#        2.51531512, 4.06828736, 5.97603809, 3.74078156, 5.47560792,
#        5.60532808, 3.02658523, 3.90965475, 4.01783353, 4.12680825,
#        5.29524027, 3.79042404, 3.35783669, 1.8736949 , 3.76149217,
#        3.68564959, 2.48669114, 3.15575039, 2.68274873, 0.47670326,
#        3.33122165, 3.27331626, 3.2099893 , 3.20623816, 1.50199562,
#        2.98724782, 1.18707191, 5.90029634, 2.49624751, 2.61901553,
#        0.67727497, 3.00548844, 3.07058568, 2.85969002, 3.64147244,
#        3.48704245, 1.37076414, 4.75751839, 4.82061455, 4.72375083,
#        4.24665164, 1.83307834, 2.85881045, 4.29922678, 2.64712883,
#        2.59446835, 5.34201522, 2.6862805 , 2.35080938, 0.96375976,
#        3.95772283, 3.38112469, 1.48517864, 3.41905735, 1.76697522,
#        0.42685292, 2.70680896, 4.81140785, 3.09082526, 3.62484421,
#        4.30528917, 2.20896561, 1.11488316, 3.84443903, 3.13733141,
#        2.62063443, 3.14452763, 5.19656896, 4.57419723, 3.68860591,
#        3.43528486, 2.19447997, 1.74120342, 4.85787462, 1.69171977,
#        5.55617269, 4.2745033 , 4.27033333, 3.09749568, 3.20797145,
#        1.26763882, 2.54273591, 3.81542809, 4.02299265, 3.40192346,
#        5.13320571, 3.09733163, 3.97870053, 2.82591411, 0.81798792,
#        3.45647739, 2.5797716 , 5.84180939, 6.18268893, 5.48019383,
#        1.69994231, 2.92763519, 6.22757237, 3.0968242 , 3.26018311,
#        2.9733494 , 4.31262522, 1.01869255, 1.78315318, 2.52292856,
#        4.15963338, 5.21325102, 3.84913408, 2.96688033, 5.14361482])

# %%
y_test_pred = ridge.predict(X_test)
y_test_pred
# Out:
# array([3.23621226, 5.1072961 , 3.58752938, 3.4743703 , 2.86026069,
#        5.26326465, 1.40167105, 4.22613927, 4.5598855 , 5.50797745,
#        1.89612428, 2.82703746, 5.14010824, 5.75368142, 3.18055683,
#        0.7989574 , 0.25697139, 4.99872686, 2.01553588, 3.29127842,
#        2.96184716, 1.5235118 , 2.22561236, 3.35186135, 3.10994513,
#        1.77131772, 2.29180407, 1.95193268, 3.69968717, 4.1616122 ,
#        3.31819753, 3.03405119, 4.83271094, 3.21864574, 4.72077319,
#        3.28667208, 2.38884844, 2.90530567, 3.93185661, 4.45804298,
#        4.5130647 , 3.45455594, 3.75680121, 2.79521457, 5.208061  ,
#        3.36997746, 4.36192943, 2.23576626, 4.47211217, 2.69326044,
#        3.90236299, 4.34096455, 5.02696773, 3.39129076, 1.9711377 ,
#        4.59944472, 4.44385742, 5.3683192 , 4.25904844, 3.54630442])

# %%
y_train_predl = lasso.predict(X_train)
y_train_predl
# Out:
# array([3.33571429, 3.33571429, 3.33571429, 3.33571429, 3.33571429,
#        3.33571429, 3.33571429, 3.33571429, 3.33571429, 3.33571429,
#        3.33571429, 3.33571429, 3.33571429, 3.33571429, 3.33571429,
#        3.33571429, 3.33571429, 3.33571429, 3.33571429, 3.33571429,
#        3.33571429, 3.33571429, 3.33571429, 3.33571429, 3.33571429,
#        3.33571429, 3.33571429, 3.33571429, 3.33571429, 3.33571429,
#        3.33571429, 3.33571429, 3.33571429, 3.33571429, 3.33571429,
#        3.33571429, 3.33571429, 3.33571429, 3.33571429, 3.33571429,
#        3.33571429, 3.33571429, 3.33571429, 3.33571429, 3.33571429,
#        3.33571429, 3.33571429, 3.33571429, 3.33571429, 3.33571429,
#        3.33571429, 3.33571429, 3.33571429, 3.33571429, 3.33571429,
#        3.33571429, 3.33571429, 3.33571429, 3.33571429, 3.33571429,
#        3.33571429, 3.33571429, 3.33571429, 3.33571429, 3.33571429,
#        3.33571429, 3.33571429, 3.33571429, 3.33571429, 3.33571429,
#        3.33571429, 3.33571429, 3.33571429, 3.33571429, 3.33571429,
#        3.33571429, 3.33571429, 3.33571429, 3.33571429, 3.33571429,
#        3.33571429, 3.33571429, 3.33571429, 3.33571429, 3.33571429,
#        3.33571429, 3.33571429, 3.33571429, 3.33571429, 3.33571429,
#        3.33571429, 3.33571429, 3.33571429, 3.33571429, 3.33571429,
#        3.33571429, 3.33571429, 3.33571429, 3.33571429, 3.33571429,
#        3.33571429, 3.33571429, 3.33571429, 3.33571429, 3.33571429,
#        3.33571429, 3.33571429, 3.33571429, 3.33571429, 3.33571429,
#        3.33571429, 3.33571429, 3.33571429, 3.33571429, 3.33571429,
#        3.33571429, 3.33571429, 3.33571429, 3.33571429, 3.33571429,
#        3.33571429, 3.33571429, 3.33571429, 3.33571429, 3.33571429,
#        3.33571429, 3.33571429, 3.33571429, 3.33571429, 3.33571429,
#        3.33571429, 3.33571429, 3.33571429, 3.33571429, 3.33571429,
#        3.33571429, 3.33571429, 3.33571429, 3.33571429, 3.33571429])

# %%
y_test_predl = lasso.predict(X_test)
y_test_predl
# Out:
# array([3.33571429, 3.33571429, 3.33571429, 3.33571429, 3.33571429,
#        3.33571429, 3.33571429, 3.33571429, 3.33571429, 3.33571429,
#        3.33571429, 3.33571429, 3.33571429, 3.33571429, 3.33571429,
#        3.33571429, 3.33571429, 3.33571429, 3.33571429, 3.33571429,
#        3.33571429, 3.33571429, 3.33571429, 3.33571429, 3.33571429,
#        3.33571429, 3.33571429, 3.33571429, 3.33571429, 3.33571429,
#        3.33571429, 3.33571429, 3.33571429, 3.33571429, 3.33571429,
#        3.33571429, 3.33571429, 3.33571429, 3.33571429, 3.33571429,
#        3.33571429, 3.33571429, 3.33571429, 3.33571429, 3.33571429,
#        3.33571429, 3.33571429, 3.33571429, 3.33571429, 3.33571429,
#        3.33571429, 3.33571429, 3.33571429, 3.33571429, 3.33571429,
#        3.33571429, 3.33571429, 3.33571429, 3.33571429, 3.33571429])

# %%
## Evaluation Metrics for Regression

# %%
from sklearn import metrics

# %%
# MSE

# ridge mse
metrics.mean_squared_error(y_test,y_test_pred)
# Out:
# 3.5421181803758715

# %%
# lasso mse
metrics.mean_squared_error(y_test,y_test_predl)
# Out:
# 5.932227891156462

# %%
# RMSE

#ridge rmse
np.sqrt(metrics.mean_squared_error(y_test,y_test_pred))
# Out:
# 1.8820515881281978

# %%
# lasso rmse 
np.sqrt(metrics.mean_squared_error(y_test,y_test_predl))
# Out:
# 2.4356165320420335

# %%
# ridge training acc.

metrics.r2_score(y_train,y_train_pred)
# Out:
# 0.2879384601314886

# %%
# testing acc. of ridge

metrics.r2_score(y_test,y_test_pred)
# Out:
# 0.3974850950031592

# %%
# lasso training  acc

metrics.r2_score(y_train,y_train_predl)
# Out:
# 0.0

# %%
# testing acc. of lasso

metrics.r2_score(y_test,y_test_predl)
# Out:
# -0.00907297335868762
